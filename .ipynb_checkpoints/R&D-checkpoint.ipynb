# %%
import torch
import tiktoken

# %%
#Raw data
train_raw = open('data/ptb.train.txt', 'r').read()
test_raw = open('data/ptb.test.txt', 'r').read()
val_raw = open('data/ptb.val.txt', 'r').read()

#Split by word into an array
train_words = train_raw.split()
test_words = test_raw.split()
val_words = val_raw.split()
